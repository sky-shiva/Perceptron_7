# %%
import cv2
import os

# Create output folder if it doesn't exist
output_folder = "extracted_frames"
os.makedirs(output_folder, exist_ok=True)

# Correct way: pass video path when creating VideoCapture
video_path = r'C:\Perceptron7\WIN_20260226_19_39_21_Pro.mp4'
vidcap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not vidcap.isOpened():
    print("Error: Could not open video")
    exit()

# Get video properties
fps = vidcap.get(cv2.CAP_PROP_FPS)  # Frames per second
total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
duration = total_frames / fps

print(f"Video FPS: {fps}")
print(f"Total frames: {total_frames}")
print(f"Video duration: {duration:.2f} seconds")

# Calculate frame interval for every 2 seconds
frame_interval = int(fps * 2)  # Number of frames in 2 seconds
print(f"Taking 1 photo every {frame_interval} frames (every 2 seconds)")

count = 0
saved_count = 0

while True:
    # read() returns (success, frame)
    success, image = vidcap.read()
    
    # Break loop if no more frames
    if not success:
        break
    
    # Save only every N-th frame (every 2 seconds)
    if count % frame_interval == 0:
        # Calculate timestamp
        timestamp = count / fps
        minutes = int(timestamp // 60)
        seconds = timestamp % 60
        
        frame_filename = os.path.join(output_folder, f"frame_{saved_count:04d}_at_{minutes}m{seconds:.1f}s.jpg")
        cv2.imwrite(frame_filename, image)
        print(f"Saved: {frame_filename} (at {timestamp:.1f} seconds)")
        saved_count += 1
    
    count += 1

# Release the video capture object
vidcap.release()
print(f"Done! Extracted {saved_count} frames (1 every 2 seconds) to {output_folder}")
# Out:
# Saved: extracted_frames\frame_0000.jpg
# Saved: extracted_frames\frame_0001.jpg
# Saved: extracted_frames\frame_0002.jpg
# Saved: extracted_frames\frame_0003.jpg
# Saved: extracted_frames\frame_0004.jpg
# Saved: extracted_frames\frame_0005.jpg
# Saved: extracted_frames\frame_0006.jpg
# Saved: extracted_frames\frame_0007.jpg
# Saved: extracted_frames\frame_0008.jpg
# Saved: extracted_frames\frame_0009.jpg
# Saved: extracted_frames\frame_0010.jpg
# Saved: extracted_frames\frame_0011.jpg
# Saved: extracted_frames\frame_0012.jpg
# Saved: extracted_frames\frame_0013.jpg
# Saved: extracted_frames\frame_0014.jpg
# Saved: extracted_frames\frame_0015.jpg
# Saved: extracted_frames\frame_0016.jpg
# Saved: extracted_frames\frame_0017.jpg
# Saved: extracted_frames\frame_0018.jpg
# Saved: extracted_frames\frame_0019.jpg
# Saved: extracted_frames\frame_0020.jpg
# Saved: extracted_frames\frame_0021.jpg
# Saved: extracted_frames\frame_0022.jpg
# Saved: extracted_frames\frame_0023.jpg
# Saved: extracted_frames\frame_0024.jpg
# Saved: extracted_frames\frame_0025.jpg
# Saved: extracted_frames\frame_0026.jpg
# Saved: extracted_frames\frame_0027.jpg
# Saved: extracted_frames\frame_0028.jpg
# Saved: extracted_frames\frame_0029.jpg
# Saved: extracted_frames\frame_0030.jpg
# Saved: extracted_frames\frame_0031.jpg
# Saved: extracted_frames\frame_0032.jpg
# Saved: extracted_frames\frame_0033.jpg
# Saved: extracted_frames\frame_0034.jpg
# Saved: extracted_frames\frame_0035.jpg
# Saved: extracted_frames\frame_0036.jpg
# Saved: extracted_frames\frame_0037.jpg
# Saved: extracted_frames\frame_0038.jpg
# Saved: extracted_frames\frame_0039.jpg
# Saved: extracted_frames\frame_0040.jpg
# Saved: extracted_frames\frame_0041.jpg
# Saved: extracted_frames\frame_0042.jpg
# Saved: extracted_frames\frame_0043.jpg
# Saved: extracted_frames\frame_0044.jpg
# Saved: extracted_frames\frame_0045.jpg
# Saved: extracted_frames\frame_0046.jpg
# Saved: extracted_frames\frame_0047.jpg
# Saved: extracted_frames\frame_0048.jpg
# Saved: extracted_frames\frame_0049.jpg
# Saved: extracted_frames\frame_0050.jpg
# Saved: extracted_frames\frame_0051.jpg
# Saved: extracted_frames\frame_0052.jpg
# Saved: extracted_frames\frame_0053.jpg
# Saved: extracted_frames\frame_0054.jpg
# Saved: extracted_frames\frame_0055.jpg
# Saved: extracted_frames\frame_0056.jpg
# Saved: extracted_frames\frame_0057.jpg
# Saved: extracted_frames\frame_0058.jpg
# Saved: extracted_frames\frame_0059.jpg
# Saved: extracted_frames\frame_0060.jpg
# Saved: extracted_frames\frame_0061.jpg
# Saved: extracted_frames\frame_0062.jpg
# Saved: extracted_frames\frame_0063.jpg
# Saved: extracted_frames\frame_0064.jpg
# Saved: extracted_frames\frame_0065.jpg
# Saved: extracted_frames\frame_0066.jpg
# Saved: extracted_frames\frame_0067.jpg
# Saved: extracted_frames\frame_0068.jpg
# Saved: extracted_frames\frame_0069.jpg
# Saved: extracted_frames\frame_0070.jpg
# Saved: extracted_frames\frame_0071.jpg
# Saved: extracted_frames\frame_0072.jpg
# Saved: extracted_frames\frame_0073.jpg
# Saved: extracted_frames\frame_0074.jpg
# Saved: extracted_frames\frame_0075.jpg
# Saved: extracted_frames\frame_0076.jpg
# Saved: extracted_frames\frame_0077.jpg
# Saved: extracted_frames\frame_0078.jpg
# Saved: extracted_frames\frame_0079.jpg
# Saved: extracted_frames\frame_0080.jpg
# Saved: extracted_frames\frame_0081.jpg
# Saved: extracted_frames\frame_0082.jpg
# Saved: extracted_frames\frame_0083.jpg
# Saved: extracted_frames\frame_0084.jpg
# Saved: extracted_frames\frame_0085.jpg
# Saved: extracted_frames\frame_0086.jpg
# Saved: extracted_frames\frame_0087.jpg
# Saved: extracted_frames\frame_0088.jpg
# Saved: extracted_frames\frame_0089.jpg
# Saved: extracted_frames\frame_0090.jpg
# Saved: extracted_frames\frame_0091.jpg
# Saved: extracted_frames\frame_0092.jpg
# Saved: extracted_frames\frame_0093.jpg
# Saved: extracted_frames\frame_0094.jpg
# Saved: extracted_frames\frame_0095.jpg
# Saved: extracted_frames\frame_0096.jpg
# Saved: extracted_frames\frame_0097.jpg
# Saved: extracted_frames\frame_0098.jpg
# Saved: extracted_frames\frame_0099.jpg
# Saved: extracted_frames\frame_0100.jpg
# Saved: extracted_frames\frame_0101.jpg
# Saved: extracted_frames\frame_0102.jpg
# Saved: extracted_frames\frame_0103.jpg
# Saved: extracted_frames\frame_0104.jpg
# Saved: extracted_frames\frame_0105.jpg
# Saved: extracted_frames\frame_0106.jpg
# Saved: extracted_frames\frame_0107.jpg
# Saved: extracted_frames\frame_0108.jpg
# Saved: extracted_frames\frame_0109.jpg
# Saved: extracted_frames\frame_0110.jpg
# Saved: extracted_frames\frame_0111.jpg
# Saved: extracted_frames\frame_0112.jpg
# Saved: extracted_frames\frame_0113.jpg
# Saved: extracted_frames\frame_0114.jpg
# Saved: extracted_frames\frame_0115.jpg
# Saved: extracted_frames\frame_0116.jpg
# Saved: extracted_frames\frame_0117.jpg
# Saved: extracted_frames\frame_0118.jpg
# Saved: extracted_frames\frame_0119.jpg
# Saved: extracted_frames\frame_0120.jpg
# Saved: extracted_frames\frame_0121.jpg
# Saved: extracted_frames\frame_0122.jpg
# Saved: extracted_frames\frame_0123.jpg
# Saved: extracted_frames\frame_0124.jpg
# Saved: extracted_frames\frame_0125.jpg
# Saved: extracted_frames\frame_0126.jpg
# Saved: extracted_frames\frame_0127.jpg
# Saved: extracted_frames\frame_0128.jpg
# Saved: extracted_frames\frame_0129.jpg
# Saved: extracted_frames\frame_0130.jpg
# Saved: extracted_frames\frame_0131.jpg
# Saved: extracted_frames\frame_0132.jpg
# Saved: extracted_frames\frame_0133.jpg
# Saved: extracted_frames\frame_0134.jpg
# Saved: extracted_frames\frame_0135.jpg
# Saved: extracted_frames\frame_0136.jpg
# Saved: extracted_frames\frame_0137.jpg
# Saved: extracted_frames\frame_0138.jpg
# Saved: extracted_frames\frame_0139.jpg
# Saved: extracted_frames\frame_0140.jpg
# Saved: extracted_frames\frame_0141.jpg
# Saved: extracted_frames\frame_0142.jpg
# Saved: extracted_frames\frame_0143.jpg
# Saved: extracted_frames\frame_0144.jpg
# Saved: extracted_frames\frame_0145.jpg
# Saved: extracted_frames\frame_0146.jpg
# Saved: extracted_frames\frame_0147.jpg
# Saved: extracted_frames\frame_0148.jpg
# Saved: extracted_frames\frame_0149.jpg
# Saved: extracted_frames\frame_0150.jpg
# Saved: extracted_frames\frame_0151.jpg
# Saved: extracted_frames\frame_0152.jpg
# Saved: extracted_frames\frame_0153.jpg
# Saved: extracted_frames\frame_0154.jpg
# Saved: extracted_frames\frame_0155.jpg
# Saved: extracted_frames\frame_0156.jpg
# Saved: extracted_frames\frame_0157.jpg
# Saved: extracted_frames\frame_0158.jpg
# Saved: extracted_frames\frame_0159.jpg
# Saved: extracted_frames\frame_0160.jpg
# Saved: extracted_frames\frame_0161.jpg
# Saved: extracted_frames\frame_0162.jpg
# Saved: extracted_frames\frame_0163.jpg
# Saved: extracted_frames\frame_0164.jpg
# Saved: extracted_frames\frame_0165.jpg
# Saved: extracted_frames\frame_0166.jpg
# Saved: extracted_frames\frame_0167.jpg
# Saved: extracted_frames\frame_0168.jpg
# Saved: extracted_frames\frame_0169.jpg
# Saved: extracted_frames\frame_0170.jpg
# Saved: extracted_frames\frame_0171.jpg
# Saved: extracted_frames\frame_0172.jpg
# Saved: extracted_frames\frame_0173.jpg
# Saved: extracted_frames\frame_0174.jpg
# Saved: extracted_frames\frame_0175.jpg
# Saved: extracted_frames\frame_0176.jpg
# Saved: extracted_frames\frame_0177.jpg
# Saved: extracted_frames\frame_0178.jpg
# Saved: extracted_frames\frame_0179.jpg
# Saved: extracted_frames\frame_0180.jpg
# Saved: extracted_frames\frame_0181.jpg
# Saved: extracted_frames\frame_0182.jpg
# Saved: extracted_frames\frame_0183.jpg
# Saved: extracted_frames\frame_0184.jpg
# Saved: extracted_frames\frame_0185.jpg
# Saved: extracted_frames\frame_0186.jpg
# Saved: extracted_frames\frame_0187.jpg
# Saved: extracted_frames\frame_0188.jpg
# Saved: extracted_frames\frame_0189.jpg
# Saved: extracted_frames\frame_0190.jpg
# Saved: extracted_frames\frame_0191.jpg
# Saved: extracted_frames\frame_0192.jpg
# Saved: extracted_frames\frame_0193.jpg
# Saved: extracted_frames\frame_0194.jpg
# Saved: extracted_frames\frame_0195.jpg
# Saved: extracted_frames\frame_0196.jpg
# Saved: extracted_frames\frame_0197.jpg
# Saved: extracted_frames\frame_0198.jpg
# Saved: extracted_frames\frame_0199.jpg
# Saved: extracted_frames\frame_0200.jpg
# Saved: extracted_frames\frame_0201.jpg
# Saved: extracted_frames\frame_0202.jpg
# Saved: extracted_frames\frame_0203.jpg
# Saved: extracted_frames\frame_0204.jpg
# Saved: extracted_frames\frame_0205.jpg
# Saved: extracted_frames\frame_0206.jpg
# Saved: extracted_frames\frame_0207.jpg
# Saved: extracted_frames\frame_0208.jpg
# Saved: extracted_frames\frame_0209.jpg
# Saved: extracted_frames\frame_0210.jpg
# Saved: extracted_frames\frame_0211.jpg
# Saved: extracted_frames\frame_0212.jpg
# Saved: extracted_frames\frame_0213.jpg
# Saved: extracted_frames\frame_0214.jpg
# Saved: extracted_frames\frame_0215.jpg
# Saved: extracted_frames\frame_0216.jpg
# Saved: extracted_frames\frame_0217.jpg
# Saved: extracted_frames\frame_0218.jpg
# Saved: extracted_frames\frame_0219.jpg
# Saved: extracted_frames\frame_0220.jpg
# Saved: extracted_frames\frame_0221.jpg
# Saved: extracted_frames\frame_0222.jpg
# Saved: extracted_frames\frame_0223.jpg
# Saved: extracted_frames\frame_0224.jpg
# Saved: extracted_frames\frame_0225.jpg
# Saved: extracted_frames\frame_0226.jpg
# Saved: extracted_frames\frame_0227.jpg
# Saved: extracted_frames\frame_0228.jpg
# Saved: extracted_frames\frame_0229.jpg
# Saved: extracted_frames\frame_0230.jpg
# Saved: extracted_frames\frame_0231.jpg
# Saved: extracted_frames\frame_0232.jpg
# Saved: extracted_frames\frame_0233.jpg
# Saved: extracted_frames\frame_0234.jpg
# Saved: extracted_frames\frame_0235.jpg
# Saved: extracted_frames\frame_0236.jpg
# Saved: extracted_frames\frame_0237.jpg
# Saved: extracted_frames\frame_0238.jpg
# Saved: extracted_frames\frame_0239.jpg
# Saved: extracted_frames\frame_0240.jpg
# Saved: extracted_frames\frame_0241.jpg
# Saved: extracted_frames\frame_0242.jpg
# Saved: extracted_frames\frame_0243.jpg
# Saved: extracted_frames\frame_0244.jpg
# Saved: extracted_frames\frame_0245.jpg
# Saved: extracted_frames\frame_0246.jpg
# Saved: extracted_frames\frame_0247.jpg
# Saved: extracted_frames\frame_0248.jpg
# Saved: extracted_frames\frame_0249.jpg
# Saved: extracted_frames\frame_0250.jpg
# Saved: extracted_frames\frame_0251.jpg
# Saved: extracted_frames\frame_0252.jpg
# Saved: extracted_frames\frame_0253.jpg
# Saved: extracted_frames\frame_0254.jpg
# Saved: extracted_frames\frame_0255.jpg
# Saved: extracted_frames\frame_0256.jpg
# Saved: extracted_frames\frame_0257.jpg
# Saved: extracted_frames\frame_0258.jpg
# Saved: extracted_frames\frame_0259.jpg
# Saved: extracted_frames\frame_0260.jpg
# Saved: extracted_frames\frame_0261.jpg
# Saved: extracted_frames\frame_0262.jpg
# Saved: extracted_frames\frame_0263.jpg
# Saved: extracted_frames\frame_0264.jpg
# Saved: extracted_frames\frame_0265.jpg
# Saved: extracted_frames\frame_0266.jpg
# Saved: extracted_frames\frame_0267.jpg
# Saved: extracted_frames\frame_0268.jpg
# Saved: extracted_frames\frame_0269.jpg
# Saved: extracted_frames\frame_0270.jpg
# Saved: extracted_frames\frame_0271.jpg
# Saved: extracted_frames\frame_0272.jpg
# Saved: extracted_frames\frame_0273.jpg
# Saved: extracted_frames\frame_0274.jpg
# Saved: extracted_frames\frame_0275.jpg
# Saved: extracted_frames\frame_0276.jpg
# Saved: extracted_frames\frame_0277.jpg
# Saved: extracted_frames\frame_0278.jpg
# Saved: extracted_frames\frame_0279.jpg
# Saved: extracted_frames\frame_0280.jpg
# Saved: extracted_frames\frame_0281.jpg
# Saved: extracted_frames\frame_0282.jpg
# Saved: extracted_frames\frame_0283.jpg
# Saved: extracted_frames\frame_0284.jpg
# Saved: extracted_frames\frame_0285.jpg
# Saved: extracted_frames\frame_0286.jpg
# Saved: extracted_frames\frame_0287.jpg
# Saved: extracted_frames\frame_0288.jpg
# Saved: extracted_frames\frame_0289.jpg
# Saved: extracted_frames\frame_0290.jpg
# Saved: extracted_frames\frame_0291.jpg
# Saved: extracted_frames\frame_0292.jpg
# Saved: extracted_frames\frame_0293.jpg
# Saved: extracted_frames\frame_0294.jpg
# Saved: extracted_frames\frame_0295.jpg
# Saved: extracted_frames\frame_0296.jpg
# Saved: extracted_frames\frame_0297.jpg
# Saved: extracted_frames\frame_0298.jpg
# Saved: extracted_frames\frame_0299.jpg
# Saved: extracted_frames\frame_0300.jpg
# Saved: extracted_frames\frame_0301.jpg
# Saved: extracted_frames\frame_0302.jpg
# Saved: extracted_frames\frame_0303.jpg
# Saved: extracted_frames\frame_0304.jpg
# Saved: extracted_frames\frame_0305.jpg
# Saved: extracted_frames\frame_0306.jpg
# Saved: extracted_frames\frame_0307.jpg
# Saved: extracted_frames\frame_0308.jpg
# Saved: extracted_frames\frame_0309.jpg
# Saved: extracted_frames\frame_0310.jpg
# Saved: extracted_frames\frame_0311.jpg
# Saved: extracted_frames\frame_0312.jpg
# Saved: extracted_frames\frame_0313.jpg
# Saved: extracted_frames\frame_0314.jpg
# Saved: extracted_frames\frame_0315.jpg
# Saved: extracted_frames\frame_0316.jpg
# Saved: extracted_frames\frame_0317.jpg
# Saved: extracted_frames\frame_0318.jpg
# Saved: extracted_frames\frame_0319.jpg
# Saved: extracted_frames\frame_0320.jpg
# Saved: extracted_frames\frame_0321.jpg
# Saved: extracted_frames\frame_0322.jpg
# Saved: extracted_frames\frame_0323.jpg
# Saved: extracted_frames\frame_0324.jpg
# Saved: extracted_frames\frame_0325.jpg
# Saved: extracted_frames\frame_0326.jpg
# Saved: extracted_frames\frame_0327.jpg
# Saved: extracted_frames\frame_0328.jpg
# Done! Extracted 329 frames to extracted_frames
